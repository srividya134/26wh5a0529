# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")

DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}
# Out:
# --- Intermediate Python Core Exercise ---

# %%
# Task 1.1

raw_sensor_data = []

start_time = datetime.datetime.now()

for i in range(100):

    timestamp = (
        start_time +
        datetime.timedelta(minutes=i)
    ).strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03d}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]

    value = round(random.uniform(minimum, maximum), 2)

    raw_sensor_data.append(
        (
            timestamp,
            device_id,
            device_type,
            location,
            value
        )
    )

print("Generated", len(raw_sensor_data), "sensor readings")


# -----------------------
# Task 1.2
# -----------------------

temperature_readings = []

for reading in raw_sensor_data:

    if reading[2] == "Temperature_Sensor":

        temperature_readings.append({

            "timestamp": reading[0],

            "device_id": reading[1],

            "location": reading[3],

            "temperature_celsius": reading[4]

        })

print("Temperature readings:", len(temperature_readings))


# -----------------------
# Task 1.3
# -----------------------

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)


# -----------------------
# Task 1.4
# -----------------------

device_stats = {}

for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

for reading in raw_sensor_data:

    device = reading[2]
    value = reading[4]

    minimum, maximum = device_stats[device]

    device_stats[device] = (
        min(minimum, value),
        max(maximum, value)
    )

print(device_stats)


# -----------------------
# Task 1.5
# -----------------------

sample_string = "PythonProgrammingIsFun"

# 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

sliced_readings_2 = raw_sensor_data[::5]

# 1.5.2

substring_1 = sample_string[6:17]

substring_2 = sample_string[5::-1]

# 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

device_type_suffix = fifth_reading_device_type[-6:]

print(substring_1)
print(substring_2)
print(device_type_suffix)
# Out:
# Generated 100 sensor readings
# Temperature readings: 26
# {'OfficeA', 'Lab1', 'OfficeB', 'Lab2', 'Warehouse'}
# {'Temperature_Sensor': (18.26, 29.27), 'Humidity_Sensor': (35.18, 78.37), 'Pressure_Sensor': (980.47, 1029.28), 'Light_Sensor': (179.74, 979.25)}
# Programming
# nohtyP
# Sensor

# %%
# Task 2.1

def get_readings_by_location(readings_list, target_location):

    result = []

    for reading in readings_list:

        if reading[3] == target_location:

            result.append(reading)

    return result


# -----------------------
# Task 2.2
# -----------------------

def calculate_average_temperature(temp_data_list):

    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:

        total += reading["temperature_celsius"]

    return total / len(temp_data_list)


# -----------------------
# Task 2.3
# -----------------------

def generate_report_line(reading_dict):

    return (
        f"[{reading_dict['timestamp']}] "
        f"Device {reading_dict['device_id']} "
        f"at {reading_dict['location']}: "
        f"{reading_dict['temperature_celsius']}°C"
    )


print(get_readings_by_location(raw_sensor_data, "Lab1")[:2])

print(calculate_average_temperature(temperature_readings))

print(generate_report_line(temperature_readings[0]))
# Out:
# [('2026-08-11 07:31:41', 'DEV004', 'Pressure_Sensor', 'Lab1', 983.94), ('2026-08-11 07:34:41', 'DEV007', 'Pressure_Sensor', 'Lab1', 990.03)]
# 24.01076923076923
# [2026-08-11 07:28:41] Device DEV001 at OfficeB: 27.88°C

# %%
# Task 3.1

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):

    os.makedirs(reports_dir)

    print("Folder created.")

else:

    print("Folder already exists.")


# -----------------------
# Task 3.2
# -----------------------

first = datetime.datetime.strptime(
    raw_sensor_data[0][0],
    "%Y-%m-%d %H:%M:%S"
)

last = datetime.datetime.strptime(
    raw_sensor_data[-1][0],
    "%Y-%m-%d %H:%M:%S"
)

duration = last - first

days = duration.days

hours = duration.seconds // 3600

minutes = (duration.seconds % 3600) // 60

print(days, "days", hours, "hours", minutes, "minutes")


# -----------------------
# Task 3.3
# -----------------------

random_values = []

for i in range(5):

    random_values.append(random.randint(100,200))

print(random_values)
# Out:
# Folder created.
# 0 days 1 hours 39 minutes
# [120, 135, 187, 125, 105]

# %%
# Task 4.1

report_filename = os.path.join(
    reports_dir,
    "temperature_report.txt"
)

try:

    with open(report_filename,"w") as file:

        for reading in temperature_readings:

            file.write(
                generate_report_line(reading)
                + "\n"
            )

    print("Temperature report created.")

except IOError as e:

    print(e)


# -----------------------
# Task 4.2
# -----------------------

read_report_lines = []

try:

    with open(report_filename,"r") as file:

        read_report_lines = file.readlines()

    print("\nFirst 3 lines:\n")

    for line in read_report_lines[:3]:

        print(line.strip())

except IOError as e:

    print(e)


print("\nExercise Completed Successfully!")
# Out:
# Temperature report created.
#
# First 3 lines:
#
# [2026-08-11 07:28:41] Device DEV001 at OfficeB: 27.88°C
# [2026-08-11 07:41:41] Device DEV014 at Lab1: 28.54°C
# [2026-08-11 07:43:41] Device DEV016 at OfficeB: 18.84°C
#
# Exercise Completed Successfully!
